# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species']=df['species'].map({"setosa":0,"versicolor":1,"virginica":2})

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion = 'gini',max_depth = 2)

# %%
classifier.fit(df.iloc[:,:-1],df.iloc[:,-1])
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
#here the decision tree is overfitting. because there is no hyper parameter tuning

# %%
from sklearn import tree

# %%
plt.figure(figsize = (15,10))
tree.plot_tree(classifier,filled = True)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
#Now in this case we could have done, feature engineering anf feature selection, train test split and cross validation
# But we just used this model for learning anf kept it simple for a simple understanding of decision tree
# after the second step we can see that sample is 54 with a 49,5 split and sample is 46 with a 45 and 1 split.
# so we can prune our decision tree from there in order to avoid overfitting
# for data sets with many features we should not do post pruning. In this case we can use max_depth as 2
# always do pre pruning using grid search cv and use all the hyper parameters and use grid serch cv to select the best ones.
# when to use pre pruning: 
# when to use post pruning:
#we can also change the "criterion" to gini and lets check the model

# %%
from sklearn.model_selection import train_test_split
